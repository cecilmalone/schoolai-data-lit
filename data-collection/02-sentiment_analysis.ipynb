# %%
#!pip install pandas
#!pip install tweepy
#!pip install vaderSentiment

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @joinBioBeats: Being part of the technology...
# 1  RT @Intelligrated: Read Matt Wicks' insights i...
# 2  RT @spin_quantum: Artificial intelligence can ...
# 3  AI - Artificial Intelligence could have a majo...
# 4  We don’t trust it fully…yet. #AI is #transform...
# 5  RT @lazowska: Congratulations to #UWAllen's Li...
# 6  RT @DonnaWR8: Google has an Artificial Intelli...
# 7  RT @newscientist: Artificial intelligence is s...
# 8  RT @DonnaWR8: Google has an Artificial Intelli...
# 9  RT @TheQuint: China is moving ahead in areas l...
# 2019-08-12 19:06:00

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @joinBioBeats: Being part of the technology...
# 1   RT @Intelligrated: Read Matt Wicks' insights i...
# 2   RT @spin_quantum: Artificial intelligence can ...
# 3   AI - Artificial Intelligence could have a majo...
# 4   We don’t trust it fully…yet. #AI is #transform...
# 5   RT @lazowska: Congratulations to #UWAllen's Li...
# 6   RT @DonnaWR8: Google has an Artificial Intelli...
# 7   RT @newscientist: Artificial intelligence is s...
# 8   RT @DonnaWR8: Google has an Artificial Intelli...
# 9   RT @TheQuint: China is moving ahead in areas l...
# 10  Researchers trained machine-learning algorithm...
# 11  "China is moving ahead in areas like artificia...
# 12  Curious how #artificialintelligence can be use...
# 13  Is #AI really has complex as many FIs believe?...
# 14  6 Steps To #AI Success [#INFOGRAPHICS] \n by @...
# 15  RT @cybersecboardrm: What just happened? The r...
# 16  RT @newscientist: Artificial intelligence is s...
# 17  RT newscientist "Artificial intelligence is su...
# 18  RT @zainaladwin: What do you know about AI?Art...
# 19  RT @DonnaWR8: Google has an Artificial Intelli...
# 20  RT @newscientist: Artificial intelligence is s...
# 21  RT @DonnaWR8: Google has an Artificial Intelli...
# 22  Review of my book by ⁦@FortuneMagazine⁩  https...
# 23  RT @newscientist: Artificial intelligence is s...
# 24  RT @AlphaGammaHQ: 4 industries poised to benef...
# 25  RT @newscientist: Artificial intelligence is s...
# 26  RT @DonnaWR8: Google has an Artificial Intelli...
# 27  Tomorrow! The DAC Leadership Series continues ...
# 28  RT @MindTendencies2: In this technology era, s...
# 29  RT @economicboard: Bouwen aan de Artificial In...
# ..                                                ...
# 70  Read Matt Wicks' insights into the fast-evolvi...
# 71  RT @SSCTechnologies: Interested in #AI and #Ma...
# 72  When artificial intelligence translates the im...
# 73  80% of #B2B #marketing executives believe arti...
# 74  RT @DonnaWR8: Google has an Artificial Intelli...
# 75  RT @CIAT_: 🍌 Artificial intelligence helps #ba...
# 76  'The 7 Best Examples Of #AI To Improve #Person...
# 77  RT @IndianPrism: "China is moving ahead in are...
# 78  RT @EduModScotland: This weekend we've got ses...
# 79  RT @jamesvgingerich: What Are The Risks And Be...
# 80  GE Healthcare, Fujitsu Australia announce new ...
# 81  What Better Way to Inspire New Artificial Inte...
# 82  Enjoyed chatting with @ttaulli about what to l...
# 83  @bottingkruger theoretical computer science an...
# 84  How #AI can improve #breastcancer diagnoses #i...
# 85  The #NZ Justice System is increasingly utilisi...
# 86  RT @DonnaWR8: Google has an Artificial Intelli...
# 87  RT @ProfTaranja: Data Science and artificial i...
# 88  RT @Mike60319099: “The U.S. doesn’t use the mo...
# 89  Artificial Intelligence (AI) in Healthcare Mar...
# 90  RT @Max_Fisher: Any user who watched one kiddi...
# 91  RT @IndianPrism: "China is moving ahead in are...
# 92  RT @LSIntegrates: As part of @NHSX, the #NHS w...
# 93  RT @BIPrime: New: IBM is using its AI star Wat...
# 94  RT @Nicochan33: Brain Inspires New Type Of Art...
# 95  It's true: Artificial intelligence is changing...
# 96  RT @DonnaWR8: Google has an Artificial Intelli...
# 97  RT @DonnaWR8: Google has an Artificial Intelli...
# 98  RT @DonnaWR8: Google has an Artificial Intelli...
# 99  RT @cwru: .@CaseEngineer's Anant Madabhushi (@...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...
# 1   {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'comp...
# 2   {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'comp...
# 3   {'neg': 0.146, 'neu': 0.577, 'pos': 0.277, 'co...
# 4   {'neg': 0.098, 'neu': 0.756, 'pos': 0.147, 'co...
# 5   {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'comp...
# 6   {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 7   {'neg': 0.181, 'neu': 0.69, 'pos': 0.13, 'comp...
# 8   {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 9   {'neg': 0.166, 'neu': 0.651, 'pos': 0.182, 'co...
# 10  {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'comp...
# 11  {'neg': 0.106, 'neu': 0.682, 'pos': 0.212, 'co...
# 12  {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'comp...
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14  {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'comp...
# 15  {'neg': 0.0, 'neu': 0.681, 'pos': 0.319, 'comp...
# 16  {'neg': 0.181, 'neu': 0.69, 'pos': 0.13, 'comp...
# 17  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...
# 18  {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'comp...
# 19  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 20  {'neg': 0.181, 'neu': 0.69, 'pos': 0.13, 'comp...
# 21  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.181, 'neu': 0.69, 'pos': 0.13, 'comp...
# 24  {'neg': 0.0, 'neu': 0.576, 'pos': 0.424, 'comp...
# 25  {'neg': 0.181, 'neu': 0.69, 'pos': 0.13, 'comp...
# 26  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 27  {'neg': 0.0, 'neu': 0.889, 'pos': 0.111, 'comp...
# 28  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'comp...
# 71  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compou...
# 72  {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 73  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 74  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 75  {'neg': 0.0, 'neu': 0.509, 'pos': 0.491, 'comp...
# 76  {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compou...
# 77  {'neg': 0.102, 'neu': 0.693, 'pos': 0.204, 'co...
# 78  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'comp...
# 79  {'neg': 0.126, 'neu': 0.719, 'pos': 0.156, 'co...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.0, 'neu': 0.496, 'pos': 0.504, 'comp...
# 82  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'comp...
# 83  {'neg': 0.0, 'neu': 0.693, 'pos': 0.307, 'comp...
# 84  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...
# 85  {'neg': 0.076, 'neu': 0.616, 'pos': 0.308, 'co...
# 86  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 87  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...
# 88  {'neg': 0.129, 'neu': 0.781, 'pos': 0.09, 'com...
# 89  {'neg': 0.0, 'neu': 0.65, 'pos': 0.35, 'compou...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.102, 'neu': 0.693, 'pos': 0.204, 'co...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94  {'neg': 0.0, 'neu': 0.6, 'pos': 0.4, 'compound...
# 95  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'comp...
# 96  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 97  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 98  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...
# 99  {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'comp...
#
# [100 rows x 2 columns]
